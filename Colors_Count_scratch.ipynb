# %%
from PIL import Image
import numpy as np
import os
import pandas as pd
import csv

import Target_colors

# %%
filename = 'Big Comp MotherBoard.png'
img = Image.open(filename)

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x860 at 0x159C251AE48>

# %%
size = img.size
pix_val = img.getcolors(size[0]*size[1])

# %%
pix = (173,202,184)

# %%
np.array_equal(pix,target_colors[0])
# Out:
# True

# %%
rowname = filename.split('.')[0]
row = [rowname]

num_target_colors = len(target_colors)

for set in pix_val:
    for i in range(num_target_colors):
        if np.array_equal(set[1][:3],target_colors[i]):
            row.append(set[0])
        else:
            row.append(0)
rows = [row]
os.chdir(orignial_directory)
with open('Target_Color_counts.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerows(rows)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-b82be51bad2f> in <module>
#      11             row.append(0)
#      12 rows = [row]
# ---> 13 os.chdir(orignial_directory)
#      14 with open('Target_Color_counts.csv', 'a', newline='') as csv_file:
#      15     writer = csv.writer(csv_file)
#
# NameError: name 'orignial_directory' is not defined
